# %%
#!pip install spacy-langdetect
# Out:
# Collecting spacy-langdetect
#   Downloading spacy_langdetect-0.1.2-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: pytest in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy-langdetect) (7.1.2)
# Collecting langdetect==1.0.7
#   Downloading langdetect-1.0.7.zip (998 kB)
#      -------------------------------------- 998.1/998.1 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from langdetect==1.0.7->spacy-langdetect) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (22.1.0)
# Requirement already satisfied: iniconfig in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (1.1.1)
# Requirement already satisfied: packaging in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (22.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (1.4.0)
# Requirement already satisfied: colorama in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pytest->spacy-langdetect) (0.4.6)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.7-py3-none-any.whl size=993439 sha256=3cc6d52711d958e89c4c8aff5fa1ab9534bd210a987bcc73954d29297a8d83f1
#   Stored in directory: c:\users\wei.liu\appdata\local\pip\cache\wheels\87\8c\9a\41c0647bd03b3e11ca6968d3638a4e6e764220adf2886270cb
# Successfully built langdetect
# Installing collected packages: langdetect, spacy-langdetect
# Successfully installed langdetect-1.0.7 spacy-langdetect-0.1.2

# %%
#!python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      -------------------------------------- 587.7/587.7 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from en-core-web-lg==3.5.0) (3.5.3)
# Requirement already satisfied: jinja2 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: setuptools in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (65.6.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.28.1)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (22.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (5.2.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wei.liu\appdata\local\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import pandas as pd
import numpy as np
import re
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.representation import MaximalMarginalRelevance
from hdbscan import HDBSCAN
import hdbscan
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import v_measure_score
from umap import UMAP

import time
from unidecode import unidecode

# %%
# load processed data from clean folder
df_app = pd.read_csv('data/clean/clean_uncat_app_pst.csv')
#df_csl = pd.read_csv('data/clean/clean_uncat_csl_pst.csv')
df_labeled_2223 = pd.read_csv('data/clean/cleaner_labeled_data_2223.csv')

# %% [markdown]
# ## Step 2.3 Shuffle Data

# %%
# shuffle first because some requests may be seasonal, such as drainage, shuffle to avoid the data being time biased
df_apps = df_app.sample(frac=1, random_state=123, ignore_index=True)
#df_csls = df_csl.sample(frac=1, random_state=123, ignore_index=True)

# %% [markdown]
# ## Step 3. Train-Test split

# %%
# split labeled data into train, valid, and test sets
# train set merge with other_issues to perform semi-supervised learning
# valid set for tuning hyper-parameters, test set for testing

# shuffle 
df_labeled_2223s = df_labeled_2223.sample(frac=1, random_state=123, ignore_index=True)
train_set = df_labeled_2223s.iloc[:int(0.7*df_labeled_2223s.shape[0]),:]
val_set = df_labeled_2223s.iloc[int(0.7*df_labeled_2223s.shape[0]):int(0.85*df_labeled_2223s.shape[0]),:]
tst_set = df_labeled_2223s.iloc[int(0.85*df_labeled_2223s.shape[0]):, :]

# %%
df_cmb_app = pd.concat([df_apps, train_set], axis=0, ignore_index=True)

print(df_cmb_app.shape)
# Out:
# (16972, 7)

# %%
# The original data, used for prediction after model tuning
doc_app = df_app['Description'].to_list()

doc_cmb_app = df_cmb_app['Description'].to_list()

doc_trn = train_set['Description'].to_list()
doc_val = val_set['Description'].to_list()
doc_tst = tst_set['Description'].to_list()

y_cmb_app = df_cmb_app['semi_label'].to_list()
y_trn = train_set['semi_label'].to_list()
y_val = val_set['semi_label'].to_list()
y_tst = tst_set['semi_label'].to_list()

# %% [markdown]
# # Semi-Supervised Model

# %%
# Sentence Transformers convert docs (service requests) into numeric representations
#sentence_model = SentenceTransformer("all-mpnet-base-v2")
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
# regenerate key words for topic representation
representation_model = KeyBERTInspired()
#representation_model = MaximalMarginalRelevance(diversity=0.5)

vectorizer_model = CountVectorizer(stop_words="english")
metric='euclidean'

# %%
# pre-calculate embeddings to save time
st = time.time()
dapp_embeddings = sentence_model.encode(doc_app, show_progress_bar=False)
#dcsl_embeddings = sentence_model.encode(doc_csl, show_progress_bar=False)

cmb_app_embeddings = sentence_model.encode(doc_cmb_app, show_progress_bar=False)
#cmb_csl_embeddings = sentence_model.encode(doc_cmb_csl, show_progress_bar=False)
trn_embeddings = sentence_model.encode(doc_trn, show_progress_bar=False)
val_embeddings = sentence_model.encode(doc_val, show_progress_bar=False)
tst_embeddings = sentence_model.encode(doc_tst, show_progress_bar=False)
elapsed = time.time()-st
print("Run time: " + time.strftime("%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:11], time.gmtime(elapsed)))
# Out:
# Run time: 00:13:31.00

# %% [markdown]
# ## Use the default setting to set up a baseline

# %%
# app data set
st = time.time()
topic_model_base_app = BERTopic()
                        
base_app_topics, base_app_probs = topic_model_base_app.fit_transform(doc_cmb_app, cmb_app_embeddings, y=y_cmb_app)


y_trn_base, tr_probs_base = topic_model_base_app.transform(doc_trn, trn_embeddings)
y_val_base, val_probs_base = topic_model_base_app.transform(doc_val, val_embeddings)
print(v_measure_score(y_trn_base, y_trn))
print(v_measure_score(y_val_base, y_val))

elapsed = time.time()-st
print("Run time: " + time.strftime("%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:11], time.gmtime(elapsed)))
# Out:
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 0.4303009273102496
# 0.41078062705797946
# Run time: 00:01:38.11

# %% [markdown]
# ## Random Search
# There are 4 hyper-parameters that are important for the performance of Bertopic model:
# 2 hyper-parameters for umap, which is for dimension reduction;
# and 2 hyper-parameters for hdbscan, which is for clustering documents.
# Unfortunately, due to the limitation of computing power and time, we can not use grid search for hyper-parameters tuning, which will lead to thounsands of times of model training and testing.
# Instead we'll implement a Random search.

# %%
# Generate n sets of random parameters in certain range

# number of parameter sets
n = 50

np.random.seed(1)
# n_neighbors
nnbs = np.random.randint(low=5, high=30, size=n)
# n_component
ncpts = np.random.randint(low=5,high=30, size=n)
# min_cluster_size
mc_sizes = np.random.randint(low=10, high=60, size=n)
# min_sample_size
ms_sizes = np.random.randint(low=10, high=60, size=n)

# %%
# Sentence Transformers convert docs (service requests) into numeric representations
#sentence_model = SentenceTransformer("all-mpnet-base-v2")
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
# regenerate key words for topic representation
representation_model = KeyBERTInspired()
#representation_model = MaximalMarginalRelevance(diversity=0.5)

vectorizer_model = CountVectorizer(stop_words="english")
metric='euclidean'

# %%
st = time.time()
tr_score, val_score, cnt_topics = [],[],[]
for nnb,ncpt,mcs,mss in zip(nnbs, ncpts,mc_sizes,ms_sizes):
    # UMAP model handles demension reduction which can be helpful with large datasets
    umap_model = UMAP(n_neighbors=nnb, n_components=ncpt, metric=metric, random_state=123)
    # HDB Scan works on clustering groups of similar embeddings
    hdbscan_model = HDBSCAN(min_cluster_size=mcs, min_samples=mss, prediction_data=True)
    
    topic_model_cmb_app = BERTopic(nr_topics="auto", umap_model=umap_model,embedding_model=sentence_model,\
                                   hdbscan_model=hdbscan_model, representation_model=representation_model,\
                                   vectorizer_model=vectorizer_model,min_topic_size=mcs, calculate_probabilities=True)
                        
    cmb_app_topics, cmb_app_probs = topic_model_cmb_app.fit_transform(doc_cmb_app, cmb_app_embeddings, y=y_cmb_app)

    
    cnt = max(cmb_app_topics)
    cnt_topics.append(cnt)
        
    y_trn_pred, tr_probs = topic_model_cmb_app.transform(doc_trn, trn_embeddings)
    y_val_pred, val_probs = topic_model_cmb_app.transform(doc_val, val_embeddings)
        
    tr_score.append(v_measure_score(y_trn_pred, y_trn))
    val_score.append(v_measure_score(y_val_pred, y_val))
    
elapsed = time.time()-st
print("Run time: " + time.strftime("%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:11], time.gmtime(elapsed)))
# Out:
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Run time: 01:45:05.25

# %%
d_scores = {'params':zip(nnbs, ncpts,mc_sizes,ms_sizes),'training_score':tr_score, 'val_score':val_score, 'topic_count':\
           cnt_topics}
gd_scores = pd.DataFrame(data=d_scores)
gd_scores.sort_values(by='val_score',ascending=False, inplace=True,ignore_index=True)

gd_scores
# Out:
#               params  training_score  val_score  topic_count
# 0    (24, 5, 43, 47)        0.575809   0.556108           25
# 1   (25, 28, 46, 43)        0.583999   0.552549           24
# 2   (28, 24, 33, 59)        0.582774   0.545295           20
# 3   (16, 22, 10, 51)        0.555445   0.543204           27
# 4   (16, 12, 49, 30)        0.574522   0.541159           29
# 5   (27, 20, 42, 25)        0.574882   0.537345           29
# 6   (15, 28, 54, 50)        0.575700   0.536146           21
# 7   (18, 19, 28, 46)        0.575082   0.535946           28
# 8   (14, 15, 38, 16)        0.559881   0.535879           29
# 9   (11, 20, 21, 58)        0.564084   0.531548           23
# 10  (12, 14, 23, 52)        0.525914   0.522281           27
# 11  (20, 29, 12, 31)        0.547631   0.519168           42
# 12  (10, 26, 13, 42)        0.534373   0.510858           27
# 13  (12, 28, 30, 23)        0.510397   0.486640           37
# 14   (17, 8, 23, 28)        0.501618   0.477993           38
# 15  (22, 10, 20, 35)        0.508227   0.476855           35
# 16   (14, 7, 20, 53)        0.472276   0.449637           16
# 17  (11, 18, 20, 59)        0.493988   0.447571           11
# 18   (8, 22, 44, 59)        0.469854   0.407405           17
# 19   (6, 18, 21, 15)        0.436915   0.392658           59
# 20   (5, 25, 37, 58)        0.431783   0.369315           12
# 21   (5, 11, 27, 24)        0.402025   0.365328           55
# 22  (27, 13, 17, 23)        0.312674   0.282947           32
# 23   (5, 28, 11, 19)        0.241332   0.210680           61
# 24  (22, 12, 40, 12)        0.200696   0.182552            9
# 25  (21, 21, 31, 25)        0.212276   0.180126           16
# 26  (13, 28, 38, 23)        0.192439   0.163563           14
# 27   (18, 5, 34, 30)        0.189782   0.162301           12
# 28  (28, 28, 42, 42)        0.224420   0.161552           13
# 29  (10, 20, 30, 23)        0.198297   0.159778           12
# 30  (23, 14, 14, 35)        0.201574   0.158243           13
# 31   (23, 5, 22, 32)        0.193157   0.157624           16
# 32   (13, 9, 16, 32)        0.193590   0.156837           15
# 33   (14, 9, 23, 29)        0.171872   0.156155           13
# 34  (13, 24, 51, 17)        0.172262   0.154427            9
# 35  (19, 27, 55, 42)        0.195932   0.151967           13
# 36  (28, 12, 28, 49)        0.211360   0.147759           11
# 37  (20, 17, 22, 49)        0.198939   0.142719           13
# 38  (15, 13, 17, 20)        0.175673   0.141455           17
# 39   (25, 9, 53, 47)        0.194882   0.135829           12
# 40  (14, 29, 31, 16)        0.142156   0.133576           11
# 41  (16, 22, 16, 12)        0.154151   0.132378           22
# 42  (17, 24, 17, 27)        0.164437   0.130319           16
# 43  (10, 16, 12, 17)        0.134266   0.111250           24
# 44   (12, 6, 49, 37)        0.159874   0.110963           13
# 45    (9, 8, 58, 31)        0.153183   0.100794           10
# 46  (18, 23, 18, 30)        0.148973   0.098896           15
# 47   (6, 20, 22, 34)        0.112393   0.078035            9
# 48   (23, 7, 40, 59)        0.104273   0.071602           10
# 49  (29, 15, 34, 15)        0.035766   0.034427           12

# %% [markdown]
# ### The optimal model: Although the validation score is a very critical metric for the evaluation of the model performance, there are other factor to consider here, such as number of topics, number of outliers, and the saliency of the topics, after experimenting on the top 3 sets of parameter, the following set of hyper parameters turn out to be the optimal.

# %%
# hyper-params that gain best val_score
n_nbors, n_components, min_cluster_size, min_samples = (20, 29, 12, 31)

# %%
#UMAP model handles demension reduction which can be helpful with large datasets
umap_model = UMAP(n_neighbors=n_nbors, n_components=n_components, metric=metric, random_state=123)
# HDB Scan works on clustering groups of similar embeddings
hdbscan_model = HDBSCAN(min_cluster_size=min_cluster_size, min_samples=min_samples, prediction_data=True)
st = time.time()
topic_model_op_app = BERTopic(nr_topics="auto", umap_model=umap_model,embedding_model=sentence_model, hdbscan_model=hdbscan_model, \
                       representation_model=representation_model, vectorizer_model=vectorizer_model,\
                            min_topic_size=min_cluster_size, calculate_probabilities=True)
                        
cmb_app_topics, cmb_app_probs = topic_model_op_app.fit_transform(doc_cmb_app, cmb_app_embeddings, y=y_cmb_app)



y_trn_pred_1, tr_probs_1 = topic_model_op_app.transform(doc_trn, trn_embeddings)
y_val_pred_1, val_probs_1 = topic_model_op_app.transform(doc_val, val_embeddings)
print(v_measure_score(y_trn_pred_1, y_trn))
print(v_measure_score(y_val_pred_1, y_val))

elapsed = time.time()-st
print("Run time: " + time.strftime("%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:11], time.gmtime(elapsed)))
# Out:
# C:\Users\Wei.Liu\AppData\Local\anaconda3\lib\site-packages\scipy\sparse\_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# 0.547630984087213
# 0.5191681586871684
# Run time: 00:03:32.04

# %% [markdown]
# ## Examine the Optimal model

# %%
# Model was assessed on how well-defined topics were and what topics were created. Hyperparameters can be adjusted to get different topics.
# The key to find a balance between topics that are specific but not too granular
pd.set_option('display.max_rows', None)
topic_model_op_app.get_topic_info()
# Out:
#     Topic  Count                                              Name  \
# 0      -1   5612                    -1_parked_parking_park_vehicle
# 1       0   2460            0_homeless_encampment_encampments_camp
# 2       1   1693                          1_parked_parking_rv_park
# 3       2   1441               2_potholes_pothole_sinkhole_manhole
# 4       3    622                          3_music_loud_sound_noise
# 5       4    600           4_traffic_streetlights_stoplight_lights
# 6       5    507                      5_tree_trees_branch_branches
# 7       6    447                              6_san_avenue_st_east
# 8       7    443                    7_hydrant_leaking_leak_leakage
# 9       8    348                     8_sign_stopping_signage_signs
# 10      9    314                       9_weeds_overgrown_weed_lawn
# 11     10    153                    10_barking_bark_barks_neighbor
# 12     11    145            11_driveway_driveways_blocking_blocked
# 13     12    138          12_harrassed_harrassment_police_neighbor
# 14     13    136                        13_parked_tags_vehicle_tag
# 15     14    126                  14_cart_abandoned_carts_shopping
# 16     15    124       15_sprinkler_sprinklers_irrigation_flooding
# 17     16    108                  16_playground_broken_swing_broke
# 18     17    104                     17_parked_parking_car_vehicle
# 19     18    103                18_fountain_fountains_water_faucet
# 20     19    100                      19_fence_fences_fencing_yard
# 21     20     89                       20_animal_dead_deceased_dog
# 22     21     88            21_sidewalk_sidewalks_repairs_repaired
# 23     22     84                           22_cat_cats_kitten_dead
# 24     23     81              23_contacting_contact_palmia_request
# 25     24     79  24_panhandlers_panhandling_panhandler_expressway
# 26     25     77                     25_speeding_mph_traffic_speed
# 27     26     76               26_window_windshield_parked_damaged
# 28     27     65                27_sweeping_sweep_sweeper_sweepers
# 29     28     63                    28_leashes_leash_dogs_shepherd
# 30     29     62                      29_curb_curbs_red_repainting
# 31     30     59                30_glass_shattered_broken_sidewalk
# 32     31     54                      31_tire_tires_flat_flattened
# 33     32     50            32_rooster_roosters_chickens_cockroach
# 34     33     48                  33_stadium_parking_stadiums_park
# 35     34     47                         34_tennis_nets_hoop_hoops
# 36     35     43                      35_boat_parked_boats_parking
# 37     36     38          36_restroom_bathrooms_bathroom_restrooms
# 38     37     33                                    37_junk_pu_ry_
# 39     38     33                  38_possum_opossum_possium_street
# 40     39     27                 39_box_boxes_electrical_utilities
# 41     40     21      40_restaurant_restaurants_permits_unlicensed
# 42     41     18                  41_sewer_sewage_plumbing_plumber
# 43     42     13            42_blight_neighborhood_vacant_blighted
#
#                                        Representation  \
# 0   [parked, parking, park, vehicle, driveway, sid...
# 1   [homeless, encampment, encampments, camp, side...
# 2   [parked, parking, rv, park, rvs, vehicle, stre...
# 3   [potholes, pothole, sinkhole, manhole, pavemen...
# 4   [music, loud, sound, noise, noisy, speakers, n...
# 5   [traffic, streetlights, stoplight, lights, str...
# 6   [tree, trees, branch, branches, pine, sidewalk...
# 7   [san, avenue, st, east, street, near, monterey...
# 8   [hydrant, leaking, leak, leakage, water, drain...
# 9   [sign, stopping, signage, signs, broken, stop,...
# 10  [weeds, overgrown, weed, lawn, yard, landscapi...
# 11  [barking, bark, barks, neighbor, neighbors, do...
# 12  [driveway, driveways, blocking, blocked, block...
# 13  [harrassed, harrassment, police, neighbor, sus...
# 14  [parked, tags, vehicle, tag, abandoned, car, t...
# 15  [cart, abandoned, carts, shopping, discarded, ...
# 16  [sprinkler, sprinklers, irrigation, flooding, ...
# 17  [playground, broken, swing, broke, swings, sli...
# 18  [parked, parking, car, vehicle, suv, hydrant, ...
# 19  [fountain, fountains, water, faucet, drought, ...
# 20  [fence, fences, fencing, yard, shed, sidewalk,...
# 21  [animal, dead, deceased, dog, cow, rat, bird, ...
# 22  [sidewalk, sidewalks, repairs, repaired, repai...
# 23  [cat, cats, kitten, dead, street, kittens, dec...
# 24  [contacting, contact, palmia, request, address...
# 25  [panhandlers, panhandling, panhandler, express...
# 26  [speeding, mph, traffic, speed, speeds, speedb...
# 27  [window, windshield, parked, damaged, broke, b...
# 28  [sweeping, sweep, sweeper, sweepers, sweeped, ...
# 29  [leashes, leash, dogs, shepherd, walk, barking...
# 30  [curb, curbs, red, repainting, repaint, repain...
# 31  [glass, shattered, broken, sidewalk, roadway, ...
# 32  [tire, tires, flat, flattened, parked, vehicle...
# 33  [rooster, roosters, chickens, cockroach, parro...
# 34  [stadium, parking, stadiums, park, parked, eve...
# 35  [tennis, nets, hoop, hoops, court, volleyball,...
# 36  [boat, parked, boats, parking, vessel, trailer...
# 37  [restroom, bathrooms, bathroom, restrooms, toi...
# 38                       [junk, pu, ry, , , , , , , ]
# 39  [possum, opossum, possium, street, possom, dea...
# 40  [box, boxes, electrical, utilities, wire, wire...
# 41  [restaurant, restaurants, permits, unlicensed,...
# 42  [sewer, sewage, plumbing, plumber, plumbers, c...
# 43  [blight, neighborhood, vacant, blighted, blvd,...
#
#                                   Representative_Docs
# 0   [I reported this as an abandoned vehicle and 3...
# 1   [Dumped trash around corner trash can, Homeles...
# 2   [Car has been parked out in the street for sev...
# 3   [Pothole in the middle of the street , large p...
# 4           [Loud music, Music to loud , Loud music ]
# 5   [Traffic light out, Traffic light is out, Gree...
# 6   [A big tree branch fell.  Please remove the br...
# 7   [Between Santa Clara and San Fernando on the w...
# 8   [Fire hydrant is leaking water., Water leaking...
# 9   [Broken stop sign, Missing street sign. Not su...
# 10  [Overgrown weeds, Junk and Overgrown weeds in ...
# 11  [Loud barking dog at this address. It ?s been ...
# 12  [Car blocking driveway, Car blocking driveway,...
# 13  [Since 2021, the same car parks in front of my...
# 14  [Car has not moved in over a year. Expired tag...
# 15  [Abandoned shopping cart, Abandoned Shopping C...
# 16  [Broken sprinkler on path along side the schoo...
# 17  [Play structure broken, Broken playground equi...
# 18  [Car parked in front of fire hydrant, Parked i...
# 19  [Please turn on water fountain?, The water fou...
# 20  [This house side fence facing Holly old school...
# 21  [Dead animal still here, Dead animal, Dead ani...
# 22  [Sidewalk needs repaired, Sidewalk needs repai...
# 23  [Dead cat in the street., Dead cat :*( on stre...
# 24  [Thank you for contacting Santa Palmia! Our su...
# 25  [Panhandling continues during the day at Sente...
# 26  [In a span no less than a month, 5 of our neig...
# 27  [No front or back license plates and broken re...
# 28  [Monthly Street Sweeping fails to sweep area. ...
# 29  [A number of people are walking their dogs wit...
# 30  [Resident painted curb red illegally. , Curb i...
# 31  [Broken glass on the sidewalk/road, Broken gla...
# 32  [Been here almost 2 weeks with flat tire., Veh...
# 33  [Disturbing rooster ? , They still have a roos...
# 34  [No events parking violation during the 49er f...
# 35  [Tennis courts at Backesto park has windbreake...
# 36  [This boat was parked here for more than two m...
# 37  [Men ?s bathroom has graffiti. Women ?s bathro...
# 38                        [junk pu, junk pu, junk pu]
# 39  [Dead opossum on the road, Dead possum in the ...
# 40  [Electrical box is open and wires coming out, ...
# 41  [Tenth st.  Food vendor operating without lice...
# 42  [I am the managing member of Oliver Anselmo, L...
# 43  [Empire and 17 th  As usual, Guru ?s has prope...

# %%
df_cmb_app['Description'][np.array(cmb_app_topics)==23][:800].values
# Out:
# array(['do not want to save password',
#        'Can ?t create 311 account due to missing password entry on create 311 account webpage.',
#        'why a password for a trash account.....',
#        'San Jose 311 Other Issues ID #230504-000870  Lan Diep',
#        'Here are pictures of the issue I raised in issue I reported: 220410-000072.',
#        'Please update  Company - JC Dukes   Phone # 415/671-1250',
#        "page has no info, it's blank", 'Unable to open attachment',
#        'This is the second time I ?ve reported this the first time was closed and nothing was done.',
#        'The 311 mobile app does not remember my password on IOS. I ?ve change my password already and it still nags me to do it again. Every time I launch the app it forces me to enter my full email and password. There is no option to remember anything.  That makes the app very cumbersome and seems incredibly dated. Can you fix this soon?',
#        'the reason for this request was not provided.  closing the request.',
#        'Hello - The web page https://records.sanjoseca.gov is down. Can you create a way to submit issues that do not relate to a location?',
#        'Getting this error from your website over and over ',
#        'missing request details',
#        'I submitted a report which was given the number 221220-000935.  It says that it was closed, but I never heard back from my report about why it couldn ?t be taken down.  robflan1728@gmail. com',
#        'Should be enhanced to describe how to change password if you already have logged in',
#        'Hi,  I reported this issue back in July but didn ?t receive any response back .. The reference id # is 220703-000473. Thank you',
#        'I am just following up on request 230421-000054 that I opened on 04/21/2023.  I saw last week that it was closed in the system, but I did not receive e-mail notification that it was closed.   I also did not see in the  ?Comments \x9d section the reason it was closed and what the status is, as the wooden bus stop area still shows to be in the same state as it was when I reported it. Thank you for your time.',
#        'no data provided',
#        'I just signed up to create a login ID for reporting incidents, but was not asked to create a password. Then when I tried to log in and create an incident (regarding Lake Cunningham Park), it would not let me log in, because my password was missing. How can I create a password for my login ID, which is the same as my email address?',
#        'This is the error message I got as I was submitting several reports in a row. BOT the first time I have gotten this. First I got a simple error message and tried again and then I got the not a human message. Closed 311 and then it worked. It was on my 5th report in succession ',
#        'airtable refused to connect  _ I spent 10 mins to fill the form only to see the error.',
#        'I already reset my password',
#        'Hi San Jose 311! My name is Christina. I am a current residence at The Woods Appartments. My location of address is : 4300 The Woods Dr. Apt D1702, San Jose, Ca 95136. I have requested for San Jose Green Team Junk Removal to pick up a used teen stationary desk for removal of the property area. I have never made a purchase of this item myself as it was given to me. I want it to be removed being taken off the property. As I did not place out the item for residence to pick up item thinking it is up for grabs.  I had noticed online on my 311 app it shows that the items work order I ?d reference number had been closed out. ID: 220-707-000054 is closed. But when I had called San Jose Green team speaking to  them that it says that it shows as active still.   I have waiting all morning after noon on 08/19/2022 at the pick up item location specific  on the order request online a and phone but no one came to pick it up yet.    Please inform contact me directly if you have any questions, concerns, or need more information for clarifications through call text or email. Ask me directly. Be specific.   Christina (669)200-8885 Christinatransemail@gmail.com',
#        "The link doesn't work per Serene Admin 3",
#        'Thank you for contacting Santa Palmia! Our support team has received your email and will respond within 48 hours.  Providing excellent customer service is our priority. If you require immediate assistance, please don ?t hesitate to contact us at (408) 365-0871.     We look forward to connecting with you!',
#        'The reason for this service request was not provided.',
#        'I need to add to this call number 221214-000893 a video link from Google photos https://photos.app.goo.gl/K9T47hZCpmj57Es7A',
#        'Stephen Testing - disregard.', 'Your website sucks',
#        'Make sure you it works ¦. You need to add an edit or delete option to the app',
#        'Hello paintmadman Owen,   Thank you for contacting us. We have created a San Jose 311 account for you to track your requests and enter new ones. To get started, activate your account.     Activate Your Account   Details   If the activate your account link doesn\'t work, please copy and paste the following URL into the address bar of your browser:  https://idcs-9d3d48212c3c456c9976187ed782ef3b.identity.oraclecloud.com:443/ui/v1/resetpwd?token=y4Ouwn2aabOLCWg%2F53xr%2F2ef1Pb3YvYfhlseFEgZXRU%3D  Important: This link will expire on Wednesday, March 1, 2023 1:50:26 PM CST.  If you have any questions you can always call us from within San Jose at "3-1-1" or you can dial (408) 535-3500.',
#        "I'm happy to confirm that your 311 app is useless.. thanks for going above and beyond to do your job...NOT.. ",
#        'I reported 8 tickets and not a single one was responded to or actioned.  All of them were closed without ANY resolution.  Please action these and provide an update please. VL05, 220526-000693 & 220615-001032. VL06, 220526-000701 & 220615-001034. VL07, 220526-000729 & 220615-001035. VL08, 220526-000710 & 220615-001036. VL09, 220526-000711 & 220615-001038. VL11, 220527-000022 & 220615-001028. VL12, 220526-000631 & 220615-001041. VL15, 220526-000636 & 220615-001045.',
#        'did not meet the criteria',
#        'cancel the previous request regarding 1536 mackey..we had the illegal dumping crew clean up the mess... please cancel the previous report..thank you',
#        'Thank you for contacting Santa Palmia! Our support team has received your email and will respond within 48 hours.      Providing excellent customer service is our priority. If you require immediate assistance, please don ?t hesitate to contact us at (408) 365-0871.     We look forward to connecting with you!     Your Team at Santa Palmia',
#        'I would like to add my address to the Handbill Objector List and the link is not working.  Please add and confirm  588 Edelweiss Dr 95136',
#        'Thank you for your email !     Currently I am on planned vacation from 30/01/2022 to 10/02/2022 with limited access to emails, please expect delay in my response.     If you need immediate assistance during my absence, please contact Shankar Narayanan/Nirosha Natarajan.        Thanks and Regards  Anju Nair',
#        'Did not understand purpose.',
#        'you should NEVER require someone to save their password',
#        'not received', 'Please do something', 'SJ311 auto response',
#        'American oak  I used 311 instead of calling sjpd because - 1.  My mobile phone is non functional at present; 2., my landline 408-300-1985 is compromised.  Please send officer to my residence.  Thank you. - Joyce DeMattei',
#        'app is very slow and i can ?t submit requests well',
#        'Website enhancement request (Nothing to take care of at my house) Regarding the dead animal pickup request online form, consider adding functionality to update the request form.  For example, I filed a pickup request Monday morning, but Wednesday I took care of the dead animal myself. If I could update the form to mark the request resolved, I would do it to save the folks a trip. Nancy Rains 1535 Minnesota Ave San Jose, CA 408 761 7723',
#        'sj311 password',
#        "My Reference Number: 230427-000884 was closed without explaination.  The next day I saw there was still ongoing water spewing out in the street.  I tried to follow up with the 311 Live Chat & it never connected.  I then called the 311's x-3500 phone number & it took almost 10 rings before someone picked up.  They routed me to the Water Company who will be sending an inspector out.  I have no idea if the City' 311 team notified the Water Co. but it didn't seem that way.  Just want to let you know that the City's current 311 process & commumication can be improved.",
#        'Cannot process.  Not enough information.',
#        'Thank you for contacting Santa Palmia! Our support team has received your email and will respond within 48 hours.      Providing excellent customer service is our priority. If you require immediate assistance, please don ?t hesitate to contact us at (408) 365-0871.     We look forward to connecting with you!',
#        'This address was report before twice,  seems like no actions were taken please review thanks',
#        "Already gave it about your address selection.  Fix your programming it is horrible. It will not accept any address you type in,  you have to click submit submit and all of a sudden like 20 minutes later it'll take it. Very very frustrating. Such a great app that does not work right",
#        'Stephen Testing, no action needed.',
#        "This the request for new garbage container.  When you enter the street address, it does not have the drop down menu.  So I'm not able to complete my replacement request.  Please fix your submission form fields.",
#        'Thank you for contacting Santa Palmia! Our support team has received your email and will respond within 48 hours.      Providing excellent customer service is our priority. If you require immediate assistance, please don ?t hesitate to contact us at (408) 365-0871.     We look forward to connecting with you!     Your Team at Santa Palmia   Chats Chats Knowledge ',
#        "Hi mi name is Patricia,i'm a taxi driver from Madrid, Spain; i'm looking for Sergio Jimenez, he forgot his phone in my car, i need to contact to him to talk about the phone, can you question Sergio if he can call me please or send me a e-mail, thanks and i'm so sorry i know this is not the best option to find him. patriciamelconperez@gmail.com or @ghoezz_ on Instagram",
#        'Test this is not a real report. please close. Test for 311',
#        'Dear San Jose City  This Problem is about My Account on LinkedIn.com. I spent 12 years building my account until the day that customer support stopped access to the account on LinkedIn.com. I have never submitted a post even 1 time and could not get to understand the reasons they locked the account. I submitted many appeals but the customer Support did not want to state or explain the problem in any transparent way, a zero transparency and zero communicative service.    This decision is absolutely unfair and is never appreciated, a discouraging and flawed user policies that do not serve the benefit of a customer. Mistakes and bad policies have happened in LinkedIn and many other companies. The path does not go both ways, and the design of rules there is lacking significantly. There is not a point of using a service if the website is not even willing to resolve simple problems. Given their capabilities, the website needs to live up to the standards and expectations for user service.   I disagree with this decision and will never be okay with this zero transparency user service. Customer support needs to state the problem so I can resolve it.  An Official needs to contact LinkedIn.com customer support to review the appeal and restore access to the account. It would be greatly appreciated if you can help resolve this problem. Please help!        Problem: Restoring Account Access, on  LinkedIn.com  LinkedIn Account Recovery Appeal [Case: 220629-016349] Reference # 220629-016349 Support: linkedin_support@cs.linkedin.com Account: mo.alaoudi@gmail.com    ',
#        'Stephen Testing due to complaint',
#        'Please provide a reason for this service request as nothing shows in the location or description fields.',
#        'The app never works for me. I fill it out and it won ?t let me submit my request',
#        'your 311 app is dysfunctional. why do we pay such high property taxes?',
#        'no comments ',
#        'This is a general question for the 311 app. Is the city of San Jose ever going to follow thru with enforcing code violations or is our city turning into Oakland ? Not being able to get the simplest things done is really becoming increasingly frustrating. I want a call back to explain why this can ?t be done and why my requests are closed as soon as I report them with nothing being done.',
#        "I'm discontinuing my earthlink email account and  need to change the email address used to register my 311 account.  The Account Settings page does not let me change it.  Can you help?",
#        'I submitted the following ticket: 230521-000269  I receive no notification so I logged in and noticed the status was  ?closed \x9d, without any comments. What is that?? Please advise on next steps of my last ticket.',
#        'Thank you for contacting Santa Palmia! Our support team has received your email and will respond within 48 hours.  Providing excellent customer service is our priority. If you require immediate assistance, please don ?t hesitate to contact us at (408) 365-0871.  We look forward to connecting with you! Your Team at Santa Palmia',
#        "Every couple months I receive a phone call with someone reporting to be from the San Jose Police Department or the Santa Clara County Sheriffs Office. These calls are now coming to by wife as well. When I have challenged the caller in the past by telling them I will call back in though the main line when they are at their desk, they freak, so I know it's a fraud call. But often times I leave the call unreturned as I have no outstanding business with either. Q: Is there a number or website for both organizations that I can use to validate that a caller is or isn't a member of law enforcement. If genuine, I do want to help, but only after validation of the caller.   Thanks, Chris",
#        'Follow up on Tracking #230404-000027  Thank you, Darren Futagaki',
#        'How come my last two reports are closed ? One was on 1-29-22 and the other on 1-31-22.  I believe it ?s a code violation if you leave your garage and recycling carts out in your front yard where they are visible. This is an ongoing problem for over two years and this is the third or fourth time I ?ve reported this. I would like conformation that something is being done to correct this issue.',
#        'Santa Rita Way. I have reported this before so it seems like a recurring issue.',
#        'Please disregard ID# 220823-000851. ',
#        ' Thank you for contacting San Jose 311 City services & information. We did not receive actual request details.  If you still need assistance please contact our office Monday-Friday, 8:00am-5:00pm at 408-535-3500 or 311. Or you may enter a new report, including the necessary details so that we may assist with your concern.  If you have further questions we can be reached at the number below.  If you have further questions, we can be reached at the number below.   Customer Contact Center City of San Jose 200 E Santa Clara St San Jose, CA  95113 (408) 535-3500 or 3-1-1 ',
#        ' Thank you for contacting San Jose 311 City services & information. We did not receive actual request details.  If you still need assistance please contact our office Monday-Friday, 8:00am-5:00pm at 408-535-3500 or 311. Or you may enter a new report, including the necessary details so that we may assist with your concern.  If you have further questions we can be reached at the number below.  If you have further questions, we can be reached at the number below.   Customer Contact Center City of San Jose 200 E Santa Clara St San Jose, CA  95113 (408) 535-3500 or 3-1-1 ',
#        'password reset',
#        "volunteer info. (I think the other request got closed but I don't know why)",
#        'Request from Sup Avilla / Cpt Trayer / Council office of David Cohen',
#        'Second request.  You sent an email regarding the original request stating it ?s already been reported and closed the request. However the item has still not been removed and as you can see is dangerous and an eye sore.',
#        'It ?s at the corner of Santa Clara and 21st, this is the second time I put in a report and the last one was closed without it being picked up',
#        'Let  me know if any more info is needed.'], dtype=object)

# %%
topic_model_op_2223.save('model_cmb_op_2223')

# %% [markdown]
# ## topic merging

# %%
topics_to_merge_app = [[0,24],[1,11,13,17,26,31,33,35],[4,21],[5,9],[7,15,18],[8,29],[10,20,22,28,32,38],[14,27,30],[16,34]]
topic_model_op_app.merge_topics(doc_cmb_app, topics_to_merge_app)

cmb_app_mg_topics = topic_model_op_app.topics_[:]

topic_model_op_app.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1   5612            -1_parked_parking_park_vehicle
# 1       0   2539   0_homeless_encampments_encampment_trash
# 2       1   2299             1_parked_parking_vehicle_park
# 3       2   1441       2_potholes_pothole_sinkhole_manhole
# 4       3    821              3_tree_trees_branches_branch
# 5       4    688      4_lights_green_stoplight_streetlight
# 6       5    670            5_leaking_leak_leakage_hydrant
# 7       6    622                  6_music_loud_sound_noise
# 8       7    472             7_barking_bark_barks_neighbor
# 9       8    447                    8_east_near_san_avenue
# 10      9    410               9_sign_signage_signs_broken
# 11     10    250          10_cart_abandoned_carts_shopping
# 12     11    155        11_playground_park_equipment_parks
# 13     12    138  12_harrassed_harrassment_police_neighbor
# 14     13    100              13_fence_fences_fencing_yard
# 15     14     81      14_contacting_contact_palmia_address
# 16     15     77             15_speeding_mph_traffic_speed
# 17     16     38  16_restroom_bathrooms_bathroom_restrooms
# 18     17     33                            17_junk_pu_ry_
# 19     18     27         18_box_boxes_electrical_utilities
# 20     19     21  19_restaurant_permits_unlicensed_vendors
# 21     20     18          20_sewer_sewage_plumbing_plumber
# 22     21     13    21_blight_neighborhood_vacant_blighted
#
#                                        Representation  \
# 0   [parked, parking, park, vehicle, driveway, veh...
# 1   [homeless, encampments, encampment, trash, rec...
# 2   [parked, parking, vehicle, park, car, vehicles...
# 3   [potholes, pothole, sinkhole, manhole, pavemen...
# 4   [tree, trees, branches, branch, pine, overgrow...
# 5   [lights, green, stoplight, streetlight, light,...
# 6   [leaking, leak, leakage, hydrant, drainage, dr...
# 7   [music, loud, sound, noise, noisy, speakers, n...
# 8   [barking, bark, barks, neighbor, neighbors, do...
# 9   [east, near, san, avenue, west, south, park, m...
# 10  [sign, signage, signs, broken, stopping, stree...
# 11  [cart, abandoned, carts, shopping, grocery, si...
# 12  [playground, park, equipment, parks, broken, s...
# 13  [harrassed, harrassment, police, neighbor, sus...
# 14  [fence, fences, fencing, yard, shed, sidewalk,...
# 15  [contacting, contact, palmia, address, request...
# 16  [speeding, mph, traffic, speed, speeds, speedb...
# 17  [restroom, bathrooms, bathroom, restrooms, toi...
# 18                       [junk, pu, ry, , , , , , , ]
# 19  [box, boxes, electrical, utilities, wire, wire...
# 20  [restaurant, permits, unlicensed, vendors, ven...
# 21  [sewer, sewage, plumbing, plumber, plumbers, c...
# 22  [blight, neighborhood, vacant, blighted, blvd,...
#
#                                   Representative_Docs
# 0   [Double parked commercial truck in residential...
# 1   [Dumped trash around corner trash can, Homeles...
# 2   [The Vehicle is parked for 3 weeks and not mov...
# 3   [Pothole in the middle of the street , large p...
# 4   [Overgrown tree on the sidewalk, tree branches...
# 5   [The green light on 2 of the lights heading So...
# 6   [Water leaking non stop.    Lots of water goin...
# 7         [Loud music , Loud music , Very loud music]
# 8   [Neighbors dog has been barking for over two h...
# 9   [near Park Ave., On the San Fernando and Third...
# 10  [Broken stop sign, Stop sign is down, Missing ...
# 11  [Abandoned shopping cart, Abandoned shopping c...
# 12  [Climbing play structure broken. The cable net...
# 13  [Hello and good morning my name is Jahan Griff...
# 14  [This house side fence facing Holly old school...
# 15  [Thank you for contacting Santa Palmia! Our su...
# 16  [In a span no less than a month, 5 of our neig...
# 17  [Men ?s bathroom has graffiti. Women ?s bathro...
# 18                        [junk pu, junk pu, junk pu]
# 19  [Utility box damaged (falling off)..., There i...
# 20  [Unlicensed food vendor.  , Tenth st.  Food ve...
# 21  [I am the managing member of Oliver Anselmo, L...
# 22  [This property was purchased YEARS ago and is ...

# %%
y_trn_pred, trn_probs = topic_model_op_app.transform(doc_trn, trn_embeddings)
y_val_pred, val_probs = topic_model_op_app.transform(doc_val, val_embeddings)


print(v_measure_score(y_trn_pred, y_trn))
print(v_measure_score(y_val_pred, y_val))
# Out:
# 0.5842848718322512
# 0.5528093922639147

# %%
# Predict on 2223 other issues data
st = time.time()
df_app_topics, df_app_probs = topic_model_op_app.transform(doc_app, dapp_embeddings)
elapsed = time.time()-st
print("Run time: " + time.strftime("%H:%M:%S.{}".format(str(elapsed % 1)[2:])[:11], time.gmtime(elapsed)))
# Out:
# Run time: 00:02:22.66

# %% [markdown]
# ## reduce outliers

# %%
# valiation score after topic merging and outlier reduction 
dist_val_pred = topic_model_op_app.reduce_outliers(doc_val, y_val_pred, strategy="distributions", distributions_params={'window':3,'stride':1})
v_measure_score(dist_val_pred, y_val)
# Out:
# 0.591386604102205

# %%
print(f'number of potholes in val_set:{val_set[val_set.semi_label==0].shape[0]}')
print(f'number of parking in val_set: {val_set[val_set.semi_label==1].shape[0]}')
print(f'number of trash in val_set: {val_set[val_set.semi_label==2].shape[0]}')
# Out:
# number of potholes in val_set:310
# number of parking in val_set: 305
# number of trash in val_set: 179

# %%
print(100*sum((np.array(dist_val_pred)==2)&(val_set.semi_label==0))/val_set[val_set.semi_label==0].shape[0])
print(100*sum((np.array(dist_val_pred)==1)&(val_set.semi_label==1))/val_set[val_set.semi_label==1].shape[0])
print(100*(sum((np.array(dist_val_pred)==0)&(val_set.semi_label==2))+sum((np.array(dist_val_pred)==10)&(val_set.semi_label==2)))/val_set[val_set.semi_label==2].shape[0])
# Out:
# 86.12903225806451
# 88.85245901639344
# 75.41899441340782

# %%
# test set score
y_tst_pred, tst_probs = topic_model_op_app.transform(doc_tst, tst_embeddings)
dist_tst_pred = topic_model_op_app.reduce_outliers(doc_tst, y_tst_pred, strategy='distributions', distributions_params={'window':3,'stride':1})

print(f'Score of build-in method: {v_measure_score(dist_tst_pred, y_tst)}')
# Out:
# Score of build-in method: 0.6230266562336086

# %%
dapp_new_topics = topic_model_op_app.reduce_outliers(doc_app, df_app_topics, strategy="distributions", distributions_params={'window':3,'stride':1})

# %%
topic_model_op_app.update_topics(docs=doc_app, topics=dapp_new_topics)
topic_model_op_app.get_topic_info()
# Out:
#     Topic  Count                               Name  \
# 0      -1      2             -1_still_here_front_in
# 1       0   2393              0_the_homeless_and_to
# 2       1   3135                1_parked_the_for_in
# 3       2    363               2_the_road_hole_lane
# 4       3   1136               3_tree_weeds_the_and
# 5       4    885           4_light_traffic_the_turn
# 6       5    899          5_water_drain_the_leaking
# 7       6    681             6_loud_music_noise_and
# 8       7    549            7_dog_barking_dead_dogs
# 9       8    709                   8_san_ave_and_st
# 10      9    615                 9_sign_stop_the_is
# 11     10    258      10_glass_shopping_cart_street
# 12     11    320      11_park_the_playground_broken
# 13     12    303                    12_my_he_to_and
# 14     13    202                13_fence_the_and_to
# 15     14    159   14_request_service_update_status
# 16     15    145         15_speed_speeding_to_bumps
# 17     16     65  16_bathroom_toilet_restroom_women
# 18     17     49               17_junk_pu_full_with
# 19     18     96            18_box_utility_open_the
# 20     19    119    19_private_food_business_housed
# 21     20     97          20_sewer_line_sewage_city
# 22     21     85  21_blight_clean_this_neighborhood
#
#                                        Representation  \
# 0                [still, here, front, in, , , , , , ]
# 1   [the, homeless, and, to, of, trash, in, garbag...
# 2   [parked, the, for, in, and, on, this, car, is,...
# 3   [the, road, hole, lane, cover, and, is, on, it...
# 4   [tree, weeds, the, and, trees, to, is, of, bra...
# 5   [light, traffic, the, turn, green, lights, to,...
# 6   [water, drain, the, leaking, is, of, leak, sto...
# 7   [loud, music, noise, and, the, to, it, is, at,...
# 8   [dog, barking, dead, dogs, the, and, to, cat, ...
# 9   [san, ave, and, st, dr, rd, of, corner, jose, on]
# 10  [sign, stop, the, is, and, street, to, at, of,...
# 11  [glass, shopping, cart, street, the, abandoned...
# 12  [park, the, playground, broken, play, to, and,...
# 13      [my, he, to, and, was, the, me, of, in, this]
# 14  [fence, the, and, to, is, of, broken, gate, on...
# 15  [request, service, update, status, haulers, to...
# 12112    This address has roosters 1545 Michigan ave al...
# 12179    Flickinger Park Major Field - The outfield loo...
# 12204    Prostitute on corner 1st and humboldt, wearing...
# 12356    The people creating the scene depicted in the ...
# 12382    Lyndale Avenue and Rose Avenue.  The silver or...
# 12436    Suspicious person sitting on my porch, rolling...
# 12480                                 Suspicious activity
# 12831    Bad guys attempted to steal bike 0135 in the m...
# 12918    Received call from a number that came up as un...
# 12943    Hi everyone. From the photo I just send. It is...
# 12949    Our bolt lock was tampered with during the hou...
# 13118    Here's the thing. On July 4th, I biked to catc...
# 13198    I left my office and as i enter 87 ramp headin...
# Name: Description, dtype: object

# %%
df_app['final_label'] = dapp_new_topics
df_app.head()
# Out:
#    Incident_ID         Date_Created  \
# 0       899307  2022-01-01 00:43:26
# 1       899308  2022-01-01 00:45:43
# 2       899312  2022-01-01 01:52:17
# 3       899315  2022-01-01 03:57:23
# 4       899372  2022-01-01 10:16:05
#
#                                          Description       Service  len lang  \
# 0  Feldspar Dr & Senter Rd inside Spanish cove mo...  Other Issues   11   en
# 1         Extremely big and loud fireworks going off  Other Issues    7   en
# 2        Building #6 (I'd like to remain anonymous).  Other Issues    7   en
# 3  Silver leaf and south sea ct. loud music all n...  Other Issues   15   en
# 4  The right hand traffic signal at 28th street w...  Other Issues   19   en
#
#    semi_label  final_label
# 0          -1            8
# 1          -1            6
# 2          -1            0
# 3          -1            6
# 4          -1            4

# %%
final_label_dict = {-1: 'Other',
              0:'Homeless/Panhandler',
              1:'Parking Violation',
              2:'Pothole',
              3:'Plant',
              4:'Traffic Light',
              5:'Water Leakage',
              6:'Noise',
              7:'Animal',
              8:'Location Only',
              9:'Street/Sidewalk Infra',
              10:'Trash',
              11:'Parks/Play Ground',
              12:'Suspecious People/Behavior',
              13:'Fence',
              14:'Account',
              15:'Speeding',
              16:'Restroom',
              17:'Junk Pick-up',
              18:'Utility Cable/Box',
              19:'Business(tax,license, permit etc)',
              20:'Sewage/Drainage',
              21:'Neighboorhood Complaint',}

# %%
df_app['final_label_verb'] = df_app['final_label'].apply(lambda x: final_label_dict[x])
df_app.head()
# Out:
#    Incident_ID         Date_Created  \
# 0       899307  2022-01-01 00:43:26
# 1       899308  2022-01-01 00:45:43
# 2       899312  2022-01-01 01:52:17
# 3       899315  2022-01-01 03:57:23
# 4       899372  2022-01-01 10:16:05
#
#                                          Description       Service  len lang  \
# 0  Feldspar Dr & Senter Rd inside Spanish cove mo...  Other Issues   11   en
# 1         Extremely big and loud fireworks going off  Other Issues    7   en
# 2        Building #6 (I'd like to remain anonymous).  Other Issues    7   en
# 3  Silver leaf and south sea ct. loud music all n...  Other Issues   15   en
# 4  The right hand traffic signal at 28th street w...  Other Issues   19   en
#
#    semi_label  final_label     final_label_verb
# 0          -1            8        Location Only
# 1          -1            6                Noise
# 2          -1            0  Homeless/Panhandler
# 3          -1            6                Noise
# 4          -1            4        Traffic Light

# %%
df_app.to_csv('data/result/Result_uncat_pst_app.csv', index=False)
